# %%
# !pip install pymongo

import sqlite3 as sq
import pymongo
# Out:
# Collecting pymongo
#   Downloading https://files.pythonhosted.org/packages/c9/36/715c4ccace03a20cf7e8f15a670f651615744987af62fad8b48bea8f65f9/pymongo-3.9.0-cp37-cp37m-win_amd64.whl (351kB)
# Installing collected packages: pymongo
# Successfully installed pymongo-3.9.0

# %%
client = pymongo.MongoClient("mongodb://admin:8Ncg3goAG9vVLA3r@cluster0-shard-00-00-xibmg.mongodb.net:27017,cluster0-shard-00-01-xibmg.mongodb.net:27017,cluster0-shard-00-02-xibmg.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test

# %%
list(db.test.find())
# Out:
# [{'_id': ObjectId('5d9e17ff89af34c65552f562'), 'x': 1},
#  {'_id': ObjectId('5d9e183a89af34c65552f563'), 'x': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01ba'),
#   'id': 1,
#   'name': 'Aliquid iste optio reiciendi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01bb'),
#   'id': 2,
#   'name': 'Optio dolorem ex a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01bc'),
#   'id': 3,
#   'name': 'Minus c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01bd'),
#   'id': 4,
#   'name': 'Sit ut repr',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01be'),
#   'id': 5,
#   'name': 'At id recusandae expl',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01bf'),
#   'id': 6,
#   'name': 'Non nobis et of',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01c0'),
#   'id': 7,
#   'name': 'Perferendis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01c1'),
#   'id': 8,
#   'name': 'Accusantium amet quidem eve',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01c2'),
#   'id': 9,
#   'name': 'Sed nostrum inventore error m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01c3'),
#   'id': 10,
#   'name': 'Harum repellendus omnis od',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01c4'),
#   'id': 11,
#   'name': 'Itaque ut commodi,',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01c5'),
#   'id': 12,
#   'name': 'Molestiae quis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01c6'),
#   'id': 13,
#   'name': 'Ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01c7'),
#   'id': 14,
#   'name': 'Tempora quod optio possimus il',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01c8'),
#   'id': 15,
#   'name': 'Sed itaque beatae pari',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01c9'),
#   'id': 16,
#   'name': 'Quam dolor',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01ca'),
#   'id': 17,
#   'name': 'Molestias expedita',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01cb'),
#   'id': 18,
#   'name': 'Lauda',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01cc'),
#   'id': 19,
#   'name': 'Incidunt sint perferen',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01cd'),
#   'id': 20,
#   'name': 'Laboriosa',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01ce'),
#   'id': 21,
#   'name': 'Dolore esse nesciunt fugit com',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01cf'),
#   'id': 22,
#   'name': 'Dolorum nam reic',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01d0'),
#   'id': 23,
#   'name': 'Repellat ad numquam volu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01d1'),
#   'id': 24,
#   'name': 'Facere enim velit eligend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01d2'),
#   'id': 25,
#   'name': 'Sed ratione quis rep',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01d3'),
#   'id': 26,
#   'name': 'Doloribus neque',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01d4'),
#   'id': 27,
#   'name': 'Ab voluptas se',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01d5'),
#   'id': 28,
#   'name': 'Molestias m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01d6'),
#   'id': 29,
#   'name': 'In pariatur corpori',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01d7'),
#   'id': 30,
#   'name': 'Possimus ad dignissimos vel, a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01d8'),
#   'id': 31,
#   'name': 'At minus accusa',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01d9'),
#   'id': 32,
#   'name': 'Ad necess',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01da'),
#   'id': 33,
#   'name': 'Expedita c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01db'),
#   'id': 34,
#   'name': 'Voluptates sunt voluptas volu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01dc'),
#   'id': 35,
#   'name': 'Autem mollitia fuga lauda',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01dd'),
#   'id': 36,
#   'name': 'Sint quibusdam ob',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01de'),
#   'id': 37,
#   'name': 'Rerum et o',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01df'),
#   'id': 38,
#   'name': 'Doloribus dolore r',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01e0'),
#   'id': 39,
#   'name': 'Eaque su',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01e1'),
#   'id': 40,
#   'name': 'Vel molestias numqua',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01e2'),
#   'id': 41,
#   'name': 'Iste assumenda repellat q',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01e3'),
#   'id': 42,
#   'name': 'Animi labo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01e4'),
#   'id': 43,
#   'name': 'Eum culpa eaque ea omn',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01e5'),
#   'id': 44,
#   'name': 'Harum provident vel quam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01e6'),
#   'id': 45,
#   'name': 'Aspe',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01e7'),
#   'id': 46,
#   'name': 'Nisi nequ',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01e8'),
#   'id': 47,
#   'name': 'Quod tempora',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01e9'),
#   'id': 48,
#   'name': 'Porro aliq',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01ea'),
#   'id': 49,
#   'name': 'Quas',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01eb'),
#   'id': 50,
#   'name': 'Magnam eligendi quia animi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01ec'),
#   'id': 51,
#   'name': 'Officiis se',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01ed'),
#   'id': 52,
#   'name': 'Id assumend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01ee'),
#   'id': 53,
#   'name': 'Voluptatibus fu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01ef'),
#   'id': 54,
#   'name': 'Odit rat',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01f0'),
#   'id': 55,
#   'name': 'Debit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01f1'),
#   'id': 56,
#   'name': 'Cum aut quas repudia',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01f2'),
#   'id': 57,
#   'name': 'Deleniti qui quae quidem',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01f3'),
#   'id': 58,
#   'name': 'Adipisci voluptas',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01f4'),
#   'id': 59,
#   'name': 'Debitis sit ratione eos nam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01f5'),
#   'id': 60,
#   'name': 'Esse illo molestias archi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01f6'),
#   'id': 61,
#   'name': 'Sunt at itaque voluptatum d',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01f7'),
#   'id': 62,
#   'name': 'Est totam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01f8'),
#   'id': 63,
#   'name': 'Reprehenderit commodi eius',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01f9'),
#   'id': 64,
#   'name': 'Debit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01fa'),
#   'id': 65,
#   'name': 'Soluta dol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01fb'),
#   'id': 66,
#   'name': 'Vel nesc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01fc'),
#   'id': 67,
#   'name': 'Ratione quia ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01fd'),
#   'id': 68,
#   'name': 'Rerum recusandae minima',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01fe'),
#   'id': 69,
#   'name': 'Totam natus eius fugiat volu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab01ff'),
#   'id': 70,
#   'name': 'Perferendis commodi null',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0200'),
#   'id': 71,
#   'name': 'Laudantiu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0201'),
#   'id': 72,
#   'name': 'Voluptat',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0202'),
#   'id': 73,
#   'name': 'Incidunt nesciun',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0203'),
#   'id': 74,
#   'name': 'Illum amet vero',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0204'),
#   'id': 75,
#   'name': 'Suscipit exercitationem re',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0205'),
#   'id': 76,
#   'name': 'Quas enim error maxime nisi m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0206'),
#   'id': 77,
#   'name': 'Labore qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0207'),
#   'id': 78,
#   'name': 'Repudiandae deleniti unde',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0208'),
#   'id': 79,
#   'name': 'Ut do',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0209'),
#   'id': 80,
#   'name': 'Quaerat esse labore q',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab020a'),
#   'id': 81,
#   'name': 'Quidem aliq',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab020b'),
#   'id': 82,
#   'name': 'Aperiam vitae eos dolor sed',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab020c'),
#   'id': 83,
#   'name': 'Minus nobis porro',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab020d'),
#   'id': 84,
#   'name': 'In similique',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab020e'),
#   'id': 85,
#   'name': 'Culpa repellat unde',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab020f'),
#   'id': 86,
#   'name': 'Architecto i',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0210'),
#   'id': 87,
#   'name': 'A sed pariatur qua',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0211'),
#   'id': 88,
#   'name': 'Tempore assumenda aperiam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0212'),
#   'id': 89,
#   'name': 'Sed ullam tempora iusto co',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0213'),
#   'id': 90,
#   'name': 'Ipsa',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0214'),
#   'id': 91,
#   'name': 'Fugiat incidun',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0215'),
#   'id': 92,
#   'name': 'Molestiae of',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0216'),
#   'id': 93,
#   'name': 'Quae quisquam cons',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0217'),
#   'id': 94,
#   'name': 'Repellendus ea non facil',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0218'),
#   'id': 95,
#   'name': 'Quod non quibu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0219'),
#   'id': 96,
#   'name': 'Numquam velit distinctio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab021a'),
#   'id': 97,
#   'name': 'Necessitatibus nihil ex debi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab021b'),
#   'id': 98,
#   'name': 'Velit tempore nemo, na',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab021c'),
#   'id': 99,
#   'name': 'Nesciunt v',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab021d'),
#   'id': 100,
#   'name': 'Dicta enim debitis accusantiu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab021e'),
#   'id': 101,
#   'name': 'Vitae a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab021f'),
#   'id': 102,
#   'name': 'Praesentium voluptas u',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0220'),
#   'id': 103,
#   'name': 'Unde ullam mollitia? Nu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0221'),
#   'id': 104,
#   'name': 'Neque molestias qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0222'),
#   'id': 105,
#   'name': 'Officiis es',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0223'),
#   'id': 106,
#   'name': 'Beatae mi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0224'),
#   'id': 107,
#   'name': 'Mollitia nam corporis temp',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0225'),
#   'id': 108,
#   'name': 'Repudiandae repellat i',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0226'),
#   'id': 109,
#   'name': 'Laboriosam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0227'),
#   'id': 110,
#   'name': 'Nam minus amet',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0228'),
#   'id': 111,
#   'name': 'Harum quae volup',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0229'),
#   'id': 112,
#   'name': 'Impedit facere ulla',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab022a'),
#   'id': 113,
#   'name': 'Enim',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab022b'),
#   'id': 114,
#   'name': 'Dolore magni',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab022c'),
#   'id': 115,
#   'name': 'Eaque at corpori',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab022d'),
#   'id': 116,
#   'name': 'Fug',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab022e'),
#   'id': 117,
#   'name': 'Dolorum laudanti',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab022f'),
#   'id': 118,
#   'name': 'Perferendis nat',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0230'),
#   'id': 119,
#   'name': 'Cupidi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0231'),
#   'id': 120,
#   'name': 'Commodi eius dicta digniss',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0232'),
#   'id': 121,
#   'name': 'Debitis eu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0233'),
#   'id': 122,
#   'name': 'Nihil repella',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0234'),
#   'id': 123,
#   'name': 'Rem quasi minima hic sed anim',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0235'),
#   'id': 124,
#   'name': 'Sed ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0236'),
#   'id': 125,
#   'name': 'Earum vol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0237'),
#   'id': 126,
#   'name': 'Inventore tempore com',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0238'),
#   'id': 127,
#   'name': 'Repell',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0239'),
#   'id': 128,
#   'name': 'Consequatur quis recusandae qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab023a'),
#   'id': 129,
#   'name': 'Dolores ea velit mi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab023b'),
#   'id': 130,
#   'name': 'Atque blanditiis a aperiam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab023c'),
#   'id': 131,
#   'name': 'Reprehenderit sequi iu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab023d'),
#   'id': 132,
#   'name': 'Natus architecto eos, hic blan',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab023e'),
#   'id': 133,
#   'name': 'Ipsa illo quas',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab023f'),
#   'id': 134,
#   'name': 'Voluptas ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0240'),
#   'id': 135,
#   'name': 'Voluptates obcaecati quod e',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0241'),
#   'id': 136,
#   'name': 'Dolor adipisci a voluptate',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0242'),
#   'id': 137,
#   'name': 'Repellendus natus quae, n',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0243'),
#   'id': 138,
#   'name': 'Laudantium earum nam in dol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0244'),
#   'id': 139,
#   'name': 'Molestias face',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0245'),
#   'id': 140,
#   'name': 'Maiores suscipit exc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0246'),
#   'id': 141,
#   'name': 'Illum dolore perferen',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0247'),
#   'id': 142,
#   'name': 'Explicabo recusandae ma',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0248'),
#   'id': 143,
#   'name': 'Odio obcaecati hic nostrum n',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0249'),
#   'id': 144,
#   'name': 'Voluptate ali',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab024a'),
#   'id': 145,
#   'name': 'Repudiandae vitae sapiente mol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab024b'),
#   'id': 146,
#   'name': 'Ipsam cumque',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab024c'),
#   'id': 147,
#   'name': 'Fugiat quos alias eos dese',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab024d'),
#   'id': 148,
#   'name': 'Eaque impe',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab024e'),
#   'id': 149,
#   'name': 'Elige',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab024f'),
#   'id': 150,
#   'name': 'Adip',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0250'),
#   'id': 151,
#   'name': 'Fuga nemo vel mo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0251'),
#   'id': 152,
#   'name': 'Libero cumque impedit eveniet',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0252'),
#   'id': 153,
#   'name': 'Odio soluta',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0253'),
#   'id': 154,
#   'name': 'Vero nostrum duc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0254'),
#   'id': 155,
#   'name': 'Repellend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0255'),
#   'id': 156,
#   'name': 'Quod',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0256'),
#   'id': 157,
#   'name': 'Suscipit reiciend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0257'),
#   'id': 158,
#   'name': 'Voluptat',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0258'),
#   'id': 159,
#   'name': 'Porro dolor fuga quam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0259'),
#   'id': 160,
#   'name': 'Amet quo fugit aliquam sequi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab025a'),
#   'id': 161,
#   'name': 'Magni adipisci veritatis sit q',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab025b'),
#   'id': 162,
#   'name': 'Debitis enim cumque cum qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab025c'),
#   'id': 163,
#   'name': 'Dolorem eligend',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab025d'),
#   'id': 164,
#   'name': 'Autem lib',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab025e'),
#   'id': 165,
#   'name': 'Saepe assumenda perferendis f',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab025f'),
#   'id': 166,
#   'name': 'Deserunt',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0260'),
#   'id': 167,
#   'name': 'Provident soluta simil',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0261'),
#   'id': 168,
#   'name': 'In accu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0262'),
#   'id': 169,
#   'name': 'Inve',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0263'),
#   'id': 170,
#   'name': 'Placeat sapiente',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0264'),
#   'id': 171,
#   'name': 'Ducimus architecto ullam',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0265'),
#   'id': 172,
#   'name': 'Voluptate tempora rerum',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0266'),
#   'id': 173,
#   'name': 'Totam incidunt earum perspicia',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0267'),
#   'id': 174,
#   'name': 'Optio quas e',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0268'),
#   'id': 175,
#   'name': 'Ab illum invento',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0269'),
#   'id': 176,
#   'name': 'Repellat quis natus totam, s',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab026a'),
#   'id': 177,
#   'name': 'Est voluptate accusantium tem',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab026b'),
#   'id': 178,
#   'name': 'Beatae q',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab026c'),
#   'id': 179,
#   'name': 'Velit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab026d'),
#   'id': 180,
#   'name': 'Minus nequ',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab026e'),
#   'id': 181,
#   'name': 'Autem eos voluptates off',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab026f'),
#   'id': 182,
#   'name': 'Vel fug',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0270'),
#   'id': 183,
#   'name': 'Architecto repudian',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0271'),
#   'id': 184,
#   'name': 'Opti',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0272'),
#   'id': 185,
#   'name': 'Iust',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0273'),
#   'id': 186,
#   'name': 'Sapiente',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0274'),
#   'id': 187,
#   'name': 'Officiis repellat corrupti su',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0275'),
#   'id': 188,
#   'name': 'Dicta et natus e',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0276'),
#   'id': 189,
#   'name': 'At quos',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0277'),
#   'id': 190,
#   'name': 'Laborum ven',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0278'),
#   'id': 191,
#   'name': 'Exceptur',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0279'),
#   'id': 192,
#   'name': 'Reiciendis assumenda dolo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab027a'),
#   'id': 193,
#   'name': 'Poss',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab027b'),
#   'id': 194,
#   'name': 'Acc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab027c'),
#   'id': 195,
#   'name': 'Placeat esse archit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab027d'),
#   'id': 196,
#   'name': 'Enim repellendus nihil est te',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab027e'),
#   'id': 197,
#   'name': 'Ipsam incidunt t',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab027f'),
#   'id': 198,
#   'name': 'Iure',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0280'),
#   'id': 199,
#   'name': 'Illo en',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0281'),
#   'id': 200,
#   'name': 'A rem ex',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0282'),
#   'id': 201,
#   'name': 'Officiis su',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0283'),
#   'id': 202,
#   'name': 'Numquam molestias',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0284'),
#   'id': 203,
#   'name': 'Voluptates unde',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0285'),
#   'id': 204,
#   'name': 'Quae praesentium vel',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0286'),
#   'id': 205,
#   'name': 'Quas',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0287'),
#   'id': 206,
#   'name': 'Dolores aliquid inv',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0288'),
#   'id': 207,
#   'name': 'Mollitia tempore laborum eaqu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0289'),
#   'id': 208,
#   'name': 'Nobis voluptates fugiat quia',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab028a'),
#   'id': 209,
#   'name': 'Similique dolorem dolore maio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab028b'),
#   'id': 210,
#   'name': 'Sapiente',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab028c'),
#   'id': 211,
#   'name': 'Officia nisi dolore',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab028d'),
#   'id': 212,
#   'name': 'Distinctio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab028e'),
#   'id': 213,
#   'name': 'Eos quia dignissimos saepe vel',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab028f'),
#   'id': 214,
#   'name': 'Ullam neque sint eligendi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0290'),
#   'id': 215,
#   'name': 'Excepturi deleniti ab a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0291'),
#   'id': 216,
#   'name': 'Accusa',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0292'),
#   'id': 217,
#   'name': 'Reiciendis laboriosam di',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0293'),
#   'id': 218,
#   'name': 'Delectus ex',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0294'),
#   'id': 219,
#   'name': 'Pari',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0295'),
#   'id': 220,
#   'name': 'Veritatis velit facilis iste',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0296'),
#   'id': 221,
#   'name': 'Dol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0297'),
#   'id': 222,
#   'name': 'Qui iste pr',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0298'),
#   'id': 223,
#   'name': 'Deleni',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab0299'),
#   'id': 224,
#   'name': 'Reprehenderit volu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab029a'),
#   'id': 225,
#   'name': 'Accusantium vitae n',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab029b'),
#   'id': 226,
#   'name': 'Natus consequatur incidun',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab029c'),
#   'id': 227,
#   'name': 'Dignissimos a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab029d'),
#   'id': 228,
#   'name': 'Vitae modi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab029e'),
#   'id': 229,
#   'name': 'Accusantium qu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab029f'),
#   'id': 230,
#   'name': 'Reiciendis dignissimos ratio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02a0'),
#   'id': 231,
#   'name': 'Expedita provident natus volup',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02a1'),
#   'id': 232,
#   'name': 'Rerum repellat voluptas c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02a2'),
#   'id': 233,
#   'name': 'Maiores quos incidunt dolor',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02a3'),
#   'id': 234,
#   'name': 'Aper',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02a4'),
#   'id': 235,
#   'name': 'Nulla',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02a5'),
#   'id': 236,
#   'name': 'Laudantium tempora itaque',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02a6'),
#   'id': 237,
#   'name': 'Reprehenderit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02a7'),
#   'id': 238,
#   'name': 'Aliqu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02a8'),
#   'id': 239,
#   'name': 'Odio harum nam mole',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02a9'),
#   'id': 240,
#   'name': 'Arc',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02aa'),
#   'id': 241,
#   'name': 'Reprehenderit li',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02ab'),
#   'id': 242,
#   'name': 'Repr',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02ac'),
#   'id': 243,
#   'name': 'Optio m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02ad'),
#   'id': 244,
#   'name': 'Esse odit amet rep',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02ae'),
#   'id': 245,
#   'name': 'Provident nostrum minima',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02af'),
#   'id': 246,
#   'name': 'Ex nihil quae facilis a omni',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02b0'),
#   'id': 247,
#   'name': 'Dolorem quaerat sunt',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02b1'),
#   'id': 248,
#   'name': 'Distinctio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02b2'),
#   'id': 249,
#   'name': 'Repudiandae ip',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02b3'),
#   'id': 250,
#   'name': 'Iste debitis dolorum amet m',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02b4'),
#   'id': 251,
#   'name': 'Non qui vo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02b5'),
#   'id': 252,
#   'name': 'Dolorem ma',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02b6'),
#   'id': 253,
#   'name': 'Molestias labore tempore ita',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02b7'),
#   'id': 254,
#   'name': 'Vol',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02b8'),
#   'id': 255,
#   'name': 'Adipisci molest',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02b9'),
#   'id': 256,
#   'name': 'Omni',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02ba'),
#   'id': 257,
#   'name': 'Voluptatibus dolor',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02bb'),
#   'id': 258,
#   'name': 'Quo',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02bc'),
#   'id': 259,
#   'name': 'Atque aspernatur possi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02bd'),
#   'id': 260,
#   'name': 'Ullam c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02be'),
#   'id': 261,
#   'name': 'Iusto quas voluptatibu',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02bf'),
#   'id': 262,
#   'name': 'Optio qui sunt dolores, ab',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02c0'),
#   'id': 263,
#   'name': 'Illum recusandae nulla re',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02c1'),
#   'id': 264,
#   'name': 'Verita',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02c2'),
#   'id': 265,
#   'name': 'Expedita quod blanditiis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02c3'),
#   'id': 266,
#   'name': 'Mag',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02c4'),
#   'id': 267,
#   'name': 'Omnis quos aspernatur d',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02c5'),
#   'id': 268,
#   'name': 'Sunt impedit co',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02c6'),
#   'id': 269,
#   'name': 'Minima quam ea ad',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02c7'),
#   'id': 270,
#   'name': 'Suscipit quidem e',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02c8'),
#   'id': 271,
#   'name': 'Harum',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02c9'),
#   'id': 272,
#   'name': 'Dolore laborum ips',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02ca'),
#   'id': 273,
#   'name': 'Magni veniam earum corporis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02cb'),
#   'id': 274,
#   'name': 'Optio',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02cc'),
#   'id': 275,
#   'name': 'Nam fugit vel.',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02cd'),
#   'id': 276,
#   'name': 'Ut numquam quam eum, alias ius',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02ce'),
#   'id': 277,
#   'name': 'Error amet tempore nulla',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02cf'),
#   'id': 278,
#   'name': 'Deserunt a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02d0'),
#   'id': 279,
#   'name': 'Aperiam sit',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02d1'),
#   'id': 280,
#   'name': 'Asperi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02d2'),
#   'id': 281,
#   'name': 'Similique aperiam earum expli',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02d3'),
#   'id': 282,
#   'name': 'Iure h',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02d4'),
#   'id': 283,
#   'name': 'At sint ducimus nostrum i',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02d5'),
#   'id': 284,
#   'name': 'Reprehenderit temporib',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02d6'),
#   'id': 285,
#   'name': 'Molestiae quaerat maxim',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02d7'),
#   'id': 286,
#   'name': 'Maior',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02d8'),
#   'id': 287,
#   'name': 'Unde natus ut ipsa cupi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02d9'),
#   'id': 288,
#   'name': 'Praesentium atque ear',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02da'),
#   'id': 289,
#   'name': 'Rem minima',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02db'),
#   'id': 290,
#   'name': 'Provident sed soluta, sed si',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02dc'),
#   'id': 291,
#   'name': 'Natus quia veritatis',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02dd'),
#   'id': 292,
#   'name': 'Vero a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02de'),
#   'id': 293,
#   'name': 'Optio harum labori',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02df'),
#   'id': 294,
#   'name': 'Duci',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02e0'),
#   'id': 295,
#   'name': 'Ipsa elige',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02e1'),
#   'id': 296,
#   'name': 'Sunt blanditiis i',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02e2'),
#   'id': 297,
#   'name': 'Doloremque',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02e3'),
#   'id': 298,
#   'name': 'Autem ratione vitae quos, do',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02e4'),
#   'id': 299,
#   'name': 'Voluptatibus aliquid',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02e5'),
#   'id': 300,
#   'name': 'Quaerat sequi sit eius corpori',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02e6'),
#   'id': 301,
#   'name': 'Libe',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1},
#  {'_id': ObjectId('5d9e3f42061d073c5dab02e7'),
#   'id': 302,
#   'name': 'Aliquam n',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1}]
